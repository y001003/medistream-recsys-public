# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from tqdm import tqdm

import scipy.sparse as sparse
import random
import implicit
from implicit.als import AlternatingLeastSquares as ALS

# %cd /home/user_3/medistream-recsys/Script
from preprocessing import drop_columns,dict_to_column,dict_to_set,set_to_column,key_to_element

pd.set_option('display.max_rows', 300)
pd.set_option('display.max_columns', 100)
# Out:
# /home/user_3/medistream-recsys/Script

# %%
pd.read_json('/home/user_1/medistream-recsys/Script/YS/category_concat.json')
# Out:
#                                  name                        meta_description  \
# 0                 KCD 한방내과 진찰진단 가이드라인                    진료에 어려움 있을 때 먼저 찾는 책
# 1        통증치료를 위한 신경초음파와 하이드로다이섹션 테크닉  하이드로다이섹션: 포도당을 이용한 신경의 유착박리와 신경주변 환경개선
# 2    의사들이 꼭 알고 있어야 하는 응급의학 실전지침서(1-2)
# 3                           복부 초음파 정석                       정확한 복부초음파를 위한 필독서
# 4                          최소침습 안면리프팅                           안면부 지방이식과 거상술
# ..                                ...                                     ...
# 706          임상의를 위한 쉽고 안전한 도침 강의 16기            22. 9.18(일), 25(일) 오후 1시~5시
# 707               매선과 한방 미용 시술 이론과 실습
# 708          요추-골반-고관절 복합체의 평가 및 추나치료
# 709      미용 매선과 피부 부스터 시술 심화 실습 강의_3기
# 710                          매선강의 준비물
#
#          tags  regular_price                      $oid  \
# 0    [가온해미디어]         150000  5d13115e32026c0b35383897
# 1      [메디안북]         190000  5e3cb2904267e105dfff13b3
# 2      [메디안북]         130000  5e3d06b64267e105dfff13e0
# 3      [메디안북]          60000  5e3d0da94267e105dfff13ed
# 4      [메디안북]          70000  5e3d10ed4267e105dfff13f1
# ..        ...            ...                       ...
# 706        []         598000  62e1e58f119967002389d10b
# 707        []         860000  62f0acf7a670760022a3e72e
# 708        []         363000  62f5dcdf0b5b9e002b2de4cf
# 709        []         780000  630c3ff668554000236d9419
# 710        []         269000  630ec908974f2b0022f857ba
#
#              category_id_$oid m_name L_name    s_name
# 0    5cf8bbba0098b2225c5dfaa3     전문     도서  [가온해미디어]
# 1    5cf8bbba0098b2225c5dfaa3     전문     도서    [메디안북]
# 2    5cf8bbba0098b2225c5dfaa3     전문     도서    [메디안북]
# 3    5cf8bbba0098b2225c5dfaa3     전문     도서    [메디안북]
# 4    5cf8bbba0098b2225c5dfaa3     전문     도서    [메디안북]
# ..                        ...    ...    ...       ...
# 706  602f886d527223001a20995b     전문     강의        진료
# 707  602f886d527223001a20995b     전문     강의      강사특강
# 708  602f886d527223001a20995b     전문     강의        골학
# 709  602f886d527223001a20995b     전문     강의      강사특강
# 710  602f886d527223001a20995b     기타     강의      강사특강
#
# [711 rows x 9 columns]

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-07a4175e7eec> in <module>
#       1 # paid orders만 가져오기
# ----> 2 df['date_paid'] = pd.to_datetime(df['date_paid'])
#       3 df_only_paid = df[~df['date_paid'].isna()]
#       4 # # 3개월치 데이터만 가져오기
#       5 # df_date = df_only_paid[df_only_paid['date_paid'] > "2022-05-12"]
#
# NameError: name 'df' is not defined
