# %%
import pandas as pd

# %%
df1 = pd.read_json("/fastcampus-data/products/products_book_lecture.json")
df = df1.copy()
df
# Out:
#                                       _id  \
# 0    {'$oid': '5d13115e32026c0b35383897'}
# 1    {'$oid': '5d9edfe70dabe405b156e213'}
# 2    {'$oid': '5e3cb2904267e105dfff13b3'}
# 3    {'$oid': '5e3d06b64267e105dfff13e0'}
# 4    {'$oid': '5e3d0da94267e105dfff13ed'}
# ..                                    ...
# 742  {'$oid': '62e1e58f119967002389d10b'}
# 743  {'$oid': '62f0acf7a670760022a3e72e'}
# 744  {'$oid': '62f5dcdf0b5b9e002b2de4cf'}
# 745  {'$oid': '630c3ff668554000236d9419'}
# 746  {'$oid': '630ec908974f2b0022f857ba'}
#
#                               date_created  \
# 0    {'$date': '2019-06-26T06:31:58.090Z'}
# 1    {'$date': '2019-10-10T07:38:15.467Z'}
# 2    {'$date': '2020-02-07T00:42:56.629Z'}
# 3    {'$date': '2020-02-07T06:41:58.622Z'}
# 4    {'$date': '2020-02-07T07:11:37.566Z'}
# ..                                     ...
# 742  {'$date': '2022-07-28T01:25:35.123Z'}
# 743  {'$date': '2022-08-08T06:28:07.531Z'}
# 744  {'$date': '2022-08-12T04:53:51.505Z'}
# ...

# %%
df.columns
# Out:
# Index(['_id', 'date_created', 'date_updated', 'images', 'dimensions', 'name',
#        'description', 'meta_description', 'meta_title', 'tags', 'attributes',
#        'enabled', 'discontinued', 'slug', 'sku', 'code', 'tax_class',
#        'related_product_ids', 'prices', 'cost_price', 'regular_price',
#        'sale_price', 'quantity_inc', 'quantity_min', 'weight',
#        'stock_quantity', 'position', 'date_stock_expected', 'date_sale_from',
#        'date_sale_to', 'stock_tracking', 'stock_preorder', 'stock_backorder',
#        'category_id', 'category_ids', 'options', 'variants', 'three_months'],
#       dtype='object')

# %%
for i in df.columns:
    print(f"[{i}]")
    print(df[i].unique)
    print()
# Out:
# [_id]
# <bound method Series.unique of 0      {'$oid': '5d13115e32026c0b35383897'}
# 1      {'$oid': '5d9edfe70dabe405b156e213'}
# 2      {'$oid': '5e3cb2904267e105dfff13b3'}
# 3      {'$oid': '5e3d06b64267e105dfff13e0'}
# 4      {'$oid': '5e3d0da94267e105dfff13ed'}
#                        ...
# 742    {'$oid': '62e1e58f119967002389d10b'}
# 743    {'$oid': '62f0acf7a670760022a3e72e'}
# 744    {'$oid': '62f5dcdf0b5b9e002b2de4cf'}
# 745    {'$oid': '630c3ff668554000236d9419'}
# 746    {'$oid': '630ec908974f2b0022f857ba'}
# Name: _id, Length: 747, dtype: object>
#
# [date_created]
# <bound method Series.unique of 0      {'$date': '2019-06-26T06:31:58.090Z'}
# 1      {'$date': '2019-10-10T07:38:15.467Z'}
# 2      {'$date': '2020-02-07T00:42:56.629Z'}
# 3      {'$date': '2020-02-07T06:41:58.622Z'}
# 4      {'$date': '2020-02-07T07:11:37.566Z'}
#                        ...
# 742    {'$date': '2022-07-28T01:25:35.123Z'}
# 743    {'$date': '2022-08-08T06:28:07.531Z'}
# ...

# %%
df[df['discontinued'] == True]
# Out:
#                                       _id  \
# 14   {'$oid': '5db0f7090dabe405b156f2a5'}
# 36   {'$oid': '5dba38770dabe405b156f991'}
# 51   {'$oid': '5dca720f2bb59605ca3cfc86'}
# 55   {'$oid': '5d8827760dabe405b156d461'}
# 57   {'$oid': '5e3d0cbb4267e105dfff13ec'}
# 63   {'$oid': '5e3d0bc94267e105dfff13e9'}
# 71   {'$oid': '5da696740dabe405b156eb5c'}
# 72   {'$oid': '5df1f34c4267e105dffef7c9'}
# 76   {'$oid': '5e0567144267e105dfff0105'}
# 90   {'$oid': '5ec1e18de510ee503167a815'}
# 97   {'$oid': '5e818515bfe42609447845e6'}
# 99   {'$oid': '5ef4a051e510ee503167d5bd'}
# 110  {'$oid': '5ec1e190e510ee503167a817'}
# 117  {'$oid': '5e425fa34267e105dfff185b'}
# 131  {'$oid': '5e6f323bbfe4260944783790'}
# 139  {'$oid': '5ec1e18fe510ee503167a816'}
# 144  {'$oid': '5f1550c0221c8b5f77c8f35c'}
# 162  {'$oid': '5f30f7d3a0b91001bf48bd51'}
# 168  {'$oid': '5f27d24580e65f5b58a7e4a9'}
# 187  {'$oid': '5f167b2e221c8b5f77c8f6a1'}
# 213  {'$oid': '602cf6502c593a001aceac87'}
# ...

# %%
df['meta_description']
# Out:
# 0                        진료에 어려움 있을 때 먼저 찾는 책
# 1               약물남용과 과잉치료가 없는 새로운 감기 진료를 목표로
# 2      하이드로다이섹션: 포도당을 이용한 신경의 유착박리와 신경주변 환경개선
# 3
# 4                           정확한 복부초음파를 위한 필독서
#                         ...
# 742              22. 9.18(일), 25(일) 오후 1시~5시
# 743
# 744
# 745
# 746
# Name: meta_description, Length: 747, dtype: object

# %%
df[df['name'].str.contains('해부학')]
# Out:
#                                       _id  \
# 7    {'$oid': '5e3d083c4267e105dfff13e3'}
# 20   {'$oid': '5e3d0f614267e105dfff13ef'}
# 61   {'$oid': '5de4c8804267e105dffeea5a'}
# 69   {'$oid': '5e40cc8b4267e105dfff155d'}
# 214  {'$oid': '602cf652527223001a209635'}
# 221  {'$oid': '602cf6582c593a001aceac8d'}
# 234  {'$oid': '6045d81940a8110019dda9ed'}
# 261  {'$oid': '60f7d00ad26af90681b1ceae'}
# 262  {'$oid': '60f7d00b09c63a06ed1476c3'}
# 292  {'$oid': '61d7a0d87560f900324cdaa3'}
# 350  {'$oid': '62ab120708e04900234df576'}
# 409  {'$oid': '60236e092c593a001ace9ffa'}
# 552  {'$oid': '61e12e367c9ea1003fa9893d'}
# 553  {'$oid': '61e12e547c9ea1003fa98943'}
# 554  {'$oid': '61e12e6e7c9ea1003fa9894c'}
# 555  {'$oid': '61e12e897c9ea1003fa98954'}
#
#                               date_created  \
# 7    {'$date': '2020-02-07T06:48:28.966Z'}
# 20   {'$date': '2020-02-07T07:18:57.024Z'}
# 61   {'$date': '2019-12-02T08:17:04.381Z'}
# 69   {'$date': '2020-02-10T03:22:51.581Z'}
# ...

# %%
df['meta_title']
# Out:
# 0                   KCD 한방내과 진찰진단 가이드라인
# 1                              우리 아이 감기
# 2          통증치료를 위한 신경초음파와 하이드로다이섹션 테크닉
# 3      의사들이 꼭 알고 있어야 하는 응급의학 실전지침서(1-2)
# 4                             복부 초음파 정석
#                      ...
# 742            임상의를 위한 쉽고 안전한 도침 강의 16기
# 743          매선과 한방 미용 시술, 이론+실습 올인원 강의
# 744            요추-골반-고관절 복합체의 평가 및 추나치료
# 745        미용 매선과 피부 부스터 시술 심화 실습 강의_3기
# 746                            매선강의 준비물
# Name: meta_title, Length: 747, dtype: object

# %%
df.columns
# Out:
# Index(['_id', 'date_created', 'date_updated', 'images', 'dimensions', 'name',
#        'description', 'meta_description', 'meta_title', 'tags', 'attributes',
#        'enabled', 'discontinued', 'slug', 'sku', 'code', 'tax_class',
#        'related_product_ids', 'prices', 'cost_price', 'regular_price',
#        'sale_price', 'quantity_inc', 'quantity_min', 'weight',
#        'stock_quantity', 'position', 'date_stock_expected', 'date_sale_from',
#        'date_sale_to', 'stock_tracking', 'stock_preorder', 'stock_backorder',
#        'category_id', 'category_ids', 'options', 'variants', 'three_months'],
#       dtype='object')

# %%
df[df['discontinued'] == True]
# Out:
#                                       _id  \
# 14   {'$oid': '5db0f7090dabe405b156f2a5'}
# 36   {'$oid': '5dba38770dabe405b156f991'}
# 51   {'$oid': '5dca720f2bb59605ca3cfc86'}
# 55   {'$oid': '5d8827760dabe405b156d461'}
# 57   {'$oid': '5e3d0cbb4267e105dfff13ec'}
# 63   {'$oid': '5e3d0bc94267e105dfff13e9'}
# 71   {'$oid': '5da696740dabe405b156eb5c'}
# 72   {'$oid': '5df1f34c4267e105dffef7c9'}
# 76   {'$oid': '5e0567144267e105dfff0105'}
# 90   {'$oid': '5ec1e18de510ee503167a815'}
# 97   {'$oid': '5e818515bfe42609447845e6'}
# 99   {'$oid': '5ef4a051e510ee503167d5bd'}
# 110  {'$oid': '5ec1e190e510ee503167a817'}
# 117  {'$oid': '5e425fa34267e105dfff185b'}
# 131  {'$oid': '5e6f323bbfe4260944783790'}
# 139  {'$oid': '5ec1e18fe510ee503167a816'}
# 144  {'$oid': '5f1550c0221c8b5f77c8f35c'}
# 162  {'$oid': '5f30f7d3a0b91001bf48bd51'}
# 168  {'$oid': '5f27d24580e65f5b58a7e4a9'}
# 187  {'$oid': '5f167b2e221c8b5f77c8f6a1'}
# 213  {'$oid': '602cf6502c593a001aceac87'}
# ...
