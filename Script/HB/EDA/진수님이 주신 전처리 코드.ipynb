# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from tqdm import tqdm
# %cd ..
# from preprocessing import drop_columns,dict_to_column,dict_to_set,set_to_column
# pd.set_option('display.max_rows', 100)
# pd.set_option('display.max_columns', 100)

# %%
df1 = pd.read_json('/fastcampus-data/log-data/log_sampling.json')
df = df1.copy()

# %%
df
# Out:
#                                                  _metadata  \
# 0        {'bundled': ['Segment.io'], 'bundledIds': [], ...
# 1        {'bundled': ['Segment.io'], 'bundledIds': [], ...
# 2        {'bundled': ['Segment.io'], 'bundledIds': [], ...
# 3        {'bundled': ['Segment.io'], 'bundledIds': [], ...
# 4        {'bundled': ['Segment.io'], 'bundledIds': [], ...
# ...                                                    ...
# 1019664  {'bundled': ['Segment.io'], 'bundledIds': [], ...
# 1019665  {'bundled': ['Segment.io'], 'bundledIds': [], ...
# 1019666  {'bundled': ['Segment.io'], 'bundledIds': [], ...
# 1019667  {'bundled': ['Segment.io'], 'bundledIds': [], ...
# 1019668  {'bundled': ['Segment.io'], 'bundledIds': [], ...
#
#                                   anonymousId channel  \
# 0        623cef3e-6160-4ca8-ab57-f1046a946cb1  client
# 1        623cef3e-6160-4ca8-ab57-f1046a946cb1  client
# 2        623cef3e-6160-4ca8-ab57-f1046a946cb1  client
# 3        b50480bc-1b18-449a-a073-39275cea3d82  client
# 4        497f3995-1387-4c97-85af-183bcefac9c9  client
# ...                                       ...     ...
# 1019664  05480617-e770-4a51-86c6-6a1fdc01fc11  client
# 1019665  3a3b5a94-d1ba-4838-91af-d578825bce4c  client
# 1019666  3a3b5a94-d1ba-4838-91af-d578825bce4c  client
# 1019667  7d0d05c7-c2f1-4a3d-b690-b07a8300f7a0  client
# 1019668  3a3b5a94-d1ba-4838-91af-d578825bce4c  client
#
#                                                    context integrations  \
# 0        {'campaign': {}, 'ip': '220.124.80.98', 'libra...           {}
# 1        {'ip': '220.124.80.98', 'library': {'name': 'a...           {}
# 2        {'ip': '220.124.80.98', 'library': {'name': 'a...           {}
# 3        {'campaign': {}, 'ip': '110.70.46.194', 'libra...           {}
# 4        {'campaign': {}, 'ip': '104.28.102.64', 'libra...           {}
# ...                                                    ...          ...
# 1019664  {'ip': '58.122.5.19', 'library': {'name': 'ana...           {}
# 1019665  {'ip': '110.8.170.95', 'library': {'name': 'an...           {}
# 1019666  {'ip': '110.8.170.95', 'library': {'name': 'an...           {}
# 1019667  {'ip': '1.215.13.164', 'library': {'name': 'an...           {}
# 1019668  {'ip': '110.8.170.95', 'library': {'name': 'an...           {}
#
#                                          messageId         originalTimestamp  \
# 0        ajs-next-c1583afa7d4c5bf091c633d8232f9da3  2022-05-13T06:28:06.805Z
# 1        ajs-next-9b8d710113206ffe6539e3ecc587567e  2022-05-13T06:30:54.677Z
# 2        ajs-next-23c3daabb8984bada04b504404bbf197  2022-05-13T06:31:26.179Z
# 3        ajs-next-04e4e02a6a6444550572ec5e2612e8e5  2022-05-13T06:33:01.601Z
# 4        ajs-next-4286d9e866e25b67b8451692a02f297a  2022-05-13T06:40:33.953Z
# ...                                            ...                       ...
# 1019664  ajs-next-382a1a6c005807d79852ec4758975cd7  2022-08-24T01:22:21.069Z
# 1019665  ajs-next-233a73a3bbcf9d4779c2d6740a4cb998  2022-08-24T01:51:34.048Z
# 1019666  ajs-next-f817c9606f757a622fb99991cbc2d027  2022-08-24T01:52:12.507Z
# 1019667  ajs-next-a828a06511701a8470d72e36f416e406  2022-08-24T02:09:59.937Z
# 1019668  ajs-next-7f613656a89906621a30ffce1a70f5f8  2022-08-24T02:21:08.460Z
#
#                       projectId                receivedAt  \
# 0        pAzAoFnKNpLfHxRmZ2oDF4  2022-05-13T06
# 1                   None  None
# 2        ArticlesArticle  None
# 3                   None  None
# 4                   None  None
# ...                  ...   ...
# 1019664             None  None
# 1019665  ArticlesArticle  None
# 1019666  ArticlesArticle  None
# 1019667  ArticlesArticle  None
# 1019668             None  None
#
# [1019669 rows x 19 columns]

# %% [markdown]
# # preprocessing 코드 작성
# * drop해야될 컬럼에 대해 전처리합니다.
# * 컬럼의 dict 타입 key를 분리하는 작업을 합니다.
# * 컬럼 dick 안 key 들에 대해서 drop해야될 것 전처리합니다.

# %%
# drop columns 전처리
def drop_columns(delete_columns:list,df:pd.DataFrame) -> pd.DataFrame:
    # 회의 때 얘기한 컬럼 전처리
    # None or 필요 없는 컬럼
    df = df.drop(columns=delete_columns)
    return df

def dict_to_column(columns:list,df:pd.DataFrame) -> pd.DataFrame:
    for col in columns:
        key_set = dict_to_set(col,df)
        df = set_to_column(col,key_set,df)
    return df

def dict_to_set(column:str,df:pd.DataFrame) -> set:
    key_set = set()
    for i in tqdm(df[column]):
        
        # column 내용이 dict일 경우
        if isinstance(i, dict):
            key_set |= set(i.keys())
        
        # column 내용이 None type 일 경우 -> 영수님이 추가해주신 부분
        elif i == None:
            continue
        
        # column 내용이 [dict]로 감싸져있는 경우
        elif (isinstance(i, list)&len(i)>0) or (isinstance(i, list)):
            key_set |= set(i[0].keys())

    return key_set

def set_to_column(column:str,key_set:set,df:pd.DataFrame) -> pd.DataFrame:
    for key in key_set:
        
        #중복인 경우 컬럼_중복컬럼으로 추가
        if key in df.columns:
            df[column+'_'+key] = df[column].apply(lambda x: x.get(key, None) if isinstance(x, dict) else None if x==None
                                       else (x[0].get(key, None) \
                                       if isinstance(x[0],dict) else None) \
                                      )
        #중복이 아닌 경우
        else:
            df[key] = df[column].apply(lambda x: x.get(key, None) if isinstance(x, dict) else None if x==None
                                       else (x[0].get(key, None) \
                                       if isinstance(x[0],dict) else None) \
                                      )

    df = df.drop(columns=[column])
    return df

# 컬럼안 key 값이 한 개일 경우 딕셔너리만 풉니다!
def key_to_element(element_columns:list,df:pd.DataFrame)->pd.DataFrame:
    for col in columns:
        key_set = dict_to_set(col, df)
        assert len(key_set)==1, f'{col}: key가 2개 이상이므로 dict_to_column 함수 이용하세요'
        for key in key_set:
            df[col] = df[col].apply(lambda x: x.get(key,None) if isinstance(x,dict) else None)
    return df

# %%
columns = ['_metadata','context','traits','properties']
df = dict_to_column(columns, df)
delete_columns = ['properties_properties', 'properties_version','properties_type', \
                  'properties_category','properties_name']
df = drop_columns(delete_columns, df)
# Out:
# 100%|██████████| 1019669/1019669 [00:00<00:00, 1259656.77it/s]
# 100%|██████████| 1019669/1019669 [00:01<00:00, 861902.02it/s]
# 100%|██████████| 1019669/1019669 [00:00<00:00, 1727384.44it/s]
# 100%|██████████| 1019669/1019669 [00:00<00:00, 1344917.21it/s]

# %%
pwd
# Out:
# '/home/user_4/EDA'

# %%
df
# Out:
#                                   anonymousId channel integrations  \
# 0        623cef3e-6160-4ca8-ab57-f1046a946cb1  client           {}
# 1        623cef3e-6160-4ca8-ab57-f1046a946cb1  client           {}
# 2        623cef3e-6160-4ca8-ab57-f1046a946cb1  client           {}
# 2           None      ko  {'path': '/articles/47475', 'referrer': 'https...
# 3             {}   ko-KR  {'path': '/', 'referrer': 'https://medistream....
# 4             {}   ko-KR  {'path': '/', 'referrer': 'https://nid.naver.c...
# ...          ...     ...                                                ...
# 1019664     None   ko-KR  {'path': '/boards/KMSForest', 'referrer': '', ...
# 1019665     None      ko  {'path': '/articles/53800', 'referrer': 'https...
# 1019666     None      ko  {'path': '/articles/53794', 'referrer': 'https...
# 1019667     None   ko-KR  {'path': '/articles/53795', 'referrer': 'https...
# 1019668     None      ko  {'path': '/boards/KMDForest', 'referrer': 'htt...
#
#                        customerId                   referrer  \
# 0                            None                       None
# 1                            None                       None
# 2                            None     https://nid.naver.com/
# 3                            None  https://medistream.co.kr/
# 4                            None                       None
# ...                           ...                        ...
# 1019664  5d6fd2b219efa30eb29141b6                       None
# 1019665                      None  https://medistream.co.kr/
# 1019666                      None  https://medistream.co.kr/
# 1019667                      None  https://medistream.co.kr/
# 1019668  5d610ff44e77525ec5ca151a                       None
#
#                                                        url  \
# 0                                                     None
# 1                                                     None
# 2                                                     None
# 3        https://medistream.co.kr?redirect=L2FydGljbGVz...
# 4                                                     None
# ...                                                    ...
# 1019664                                               None
# 1019665                                               None
# 1019666                                               None
# 1019667                                               None
# 1019668                                               None
#
#                                                     search properties_userId  \
# 0                                                     None              None
# 1                                                     None              None
# 2                                                       {}              None
# 3        ?redirect=L2FydGljbGVzLzQ3OTQxP3V0bV9zb3VyY2U9...              None
# 4                                                     None              None
# ...                                                    ...               ...
# 1019664                                               None              None
# 1019665                                                 {}              None
# 1019666                                                 {}              None
# 1019667                                                 {}              None
# 1019668                                               None              None
#
#                           title             path
# 0                          None             None
# 1                          None             None
# 2            메디스트림 | Medistream  /articles/47475
# 3            메디스트림 | Medistream                /
# 4                          None             None
# ...                         ...              ...
# 1019664                    None             None
# 1019665      메디스트림 | Medistream  /articles/53800
# 1019666      메디스트림 | Medistream  /articles/53794
# 1019667  (5) 메디스트림 | Medistream  /articles/53795
# 1019668                    None             None
#
# [1019669 rows x 34 columns]

# %%
df.columns
# Out:
# Index(['anonymousId', 'channel', 'integrations', 'messageId',
#        'originalTimestamp', 'projectId', 'receivedAt', 'sentAt', 'timestamp',
#        'type', 'userId', 'version', 'category', 'name', 'event', 'bundled',
#        'unbundled', 'bundledIds', '_metadata_bundled', '_metadata_unbundled',
#        '_metadata_bundledIds', 'ip', 'library', 'userAgent', 'campaign',
#        'locale', 'page', 'customerId', 'referrer', 'url', 'search',
#        'properties_userId', 'title', 'path'],
#       dtype='object')

# %%
df['page'][0]
# Out:
# {'path': '/',
#  'referrer': 'https://nid.naver.com/',
#  'search': '?redirect=Lw%3D%3D&code=VTJGc2RHVmtYMSthQUsyUEgzS2x2Rkc3WXFSeDl3TDUrK3hoS2lyZyttbWZXYi9MaGxnWkxXUXk4c2VOQ0dvdWtra2s0K0dHSXVOZVUxZDkzK1g3YkE9PQ%3D%3D',
#  'title': '메디스트림 | Medistream',
#  'url': 'https://medistream.co.kr?redirect=Lw%3D%3D&code=VTJGc2RHVmtYMSthQUsyUEgzS2x2Rkc3WXFSeDl3TDUrK3hoS2lyZyttbWZXYi9MaGxnWkxXUXk4c2VOQ0dvdWtra2s0K0dHSXVOZVUxZDkzK1g3YkE9PQ%3D%3D'}
