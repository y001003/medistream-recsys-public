# %% [markdown]
# # import libraries

# %%
# import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from tqdm import tqdm

import scipy.sparse as sparse
import random

# import preprocessing codes
# %cd /home/user_3/medistream-recsys/Script
from preprocessing import drop_columns,dict_to_column,dict_to_set,set_to_column,key_to_element

pd.set_option('display.max_rows', 300)
pd.set_option('display.max_columns', 100)

# ignore warning 
import warnings
warnings.filterwarnings("ignore")
# Out:
# /home/user_3/medistream-recsys/Script

# %% [markdown]
# # Upload data

# %%
df1 = pd.read_json('/fastcampus-data/select_column_version_3.json')
df = df1.copy()

# %%
# log data의 기간(4개월)과 동일한 기간의 데이터 사용하기 위해 start date 지정 
start_date = "2022-05-12"

# paid orders만 가져오기
df['date_paid'] = pd.to_datetime(df['date_paid'])
df_only_paid = df[~df['date_paid'].isna()]

# 3개월치 데이터만 가져오기
df_date = df_only_paid[df_only_paid['date_paid'] > start_date]

# 취소 안된 것만 가져오기
complete_df = df_date[(df_date['paid'] == True) & (df_date['cancelled']==False)]
complete_df = complete_df.reset_index(drop=True)


# 이상치 제거: 국시특강, 보수교육
complete_df = complete_df[complete_df['name_x'].str.contains('국시특강') == False]
complete_df = complete_df[complete_df['name_x'].str.contains('보수교육') == False]
complete_df = complete_df.sort_values(by='date_paid')

# %% [markdown]
# # train test split

# %%
from datetime import datetime, timedelta

# 마지막 일주일을 test data로 사용
date = complete_df['date_paid'].max()-timedelta(weeks=1)
train_before_preprocess = complete_df[complete_df['date_paid'] < date]
test_before_preprocess = complete_df[complete_df['date_paid'] >= date]

# train 1개 이상 구매 기록유저에 대한 학습 진행
train_drop_row_index = train_before_preprocess['customer_id'].value_counts()[train_before_preprocess['customer_id'].value_counts()>=1].index
train = train_before_preprocess[train_before_preprocess['customer_id'].isin(train_drop_row_index)]

# %%
# 전처리할 test index 확인: 2번 이상 구매한 고객만 추출
drop_row_index = test_before_preprocess['customer_id'].value_counts()[test_before_preprocess['customer_id'].value_counts()>2].index

# 최근 구매 3개 기록을 test로 사용
test_list = []
for idx in drop_row_index:
    test_list.append(test_before_preprocess[test_before_preprocess['customer_id']==idx].iloc[:])
test = pd.concat(test_list)

# train 있는 유저에 대해서만 진행
test = test[test['customer_id'].isin(train['customer_id'])]

# %%
train.date_paid = pd.to_datetime(train.date_paid)

# %%
# date_paid에 날짜만 남기기
train.date_paid = train.date_paid.apply(lambda x: x.date)

# %% [markdown]
# # train test eda

# %% [markdown]
# ### 전처리 전후 비교

# %%
print('train 전처리 전:',len(train_before_preprocess), 'train 전처리 후:',len(train))
# Out:
# train 전처리 전: 27806 train 전처리 후: 27806

# %%
print('test 전처리 전:',len(test_before_preprocess), 'test 전처리 후:',len(test))
# Out:
# test 전처리 전: 1443 test 전처리 후: 629

# %% [markdown]
# ### user 수 비교

# %%
print('train 유저 수:',len(train.customer_id.unique()))
# Out:
# train 유저 수: 4844

# %%
print('test 유저 수:',len(test.customer_id.unique()))
# Out:
# test 유저 수: 103

# %% [markdown]
# ### item 개수 비교

# %%
print('train 아이템 수 :',len(set(train.product_ids)), 'test 아이템 수 :',len(set(test.product_ids)))
# Out:
# train 아이템 수 : 1915 test 아이템 수 : 269

# %%
print('train 만 있는 아이템 수:',  len(set(train.product_ids)-set(test.product_ids)))
# Out:
# train 만 있는 아이템 수: 1657

# %%
print('test 만 있는 아이템 수:', len(set(test.product_ids) - set(train.product_ids)))
# Out:
# test 만 있는 아이템 수: 11

# %%
print(train.shape)
print(test.shape)
# Out:
# (27806, 16)
# (629, 16)

# %% [markdown]
# # Load Transactions, Reduce Memory

# %%
train = train[['date_paid','customer_id','name_x','product_ids']]

# %%
tmp = train.groupby('customer_id').date_paid.max().reset_index()
tmp.columns = ['customer_id','max_dat']
train = train.merge(tmp,on=['customer_id'],how='left')
train['diff_dat'] = (train.max_dat - train.date_paid).dt.days

# 다른 날짜를 6보다 작은 것으로 하는건 최신의 정보를 반영하기 위함인가?
train = train.loc[train['diff_dat']<=6]
print('Train shape:',train.shape)
# Out:
# Train shape: (8520, 6)

# %%
train.diff_dat.unique()
# Out:
# array([0, 4, 1, 5, 3, 2, 6])

# %% [markdown]
# # Apriori Transformation:

# %%
#Apriori treats duplicates as a single occurence
# 한 유저당 구매한 제품들의 unique -> 중복을 없앰.
train_apri = train.groupby('customer_id')['name_x'].unique().reset_index()
train_apri
# Out:
#                    customer_id  \
# 0     5d60b9184e77525ec5ca138d
# 1     5d60b93c4e77525ec5ca1391
# 2     5d60c43f4e77525ec5ca13a8
# 3     5d60c5884e77525ec5ca13ae
# 4     5d60cab24e77525ec5ca13d5
# ...                        ...
# 4839  630871b668554000236d8b03
# 4840  630eaa6a68554000236da5d9
# 4841  630f06ee974f2b0022f85afa
# 4842  63155514c640eb0021af84fc
# 4843  63155585c640eb0021af8506
#
#                                                  name_x
# 0     [[2022전국한의학학술대회] MET에 근거한 경근추나, [2022전국한의학학술대회...
# 1     [복순도가 손막걸리 3병 고급선물세트, Freshvalley 추석  프리미엄 청도 ...
# 2     [[타스컴] 백톤디킨슨(BD) 인슐린주사기 100pcs, 진맛과 명인 특선 16호 ...
# 3     [맘 편하게 한약 처방하기, 선우항 선생님의 청구 원포인트 레슨, 신민섭 교수님의 ...
# 4                                          [숲을 보는 요통치료]
# ...                                                 ...
# 4839              [2022년 사상체질의학회 제1회 월례학술집담회 녹화본 강의(2)]
# 4840                                      [영어 진료 가이드북 ]
# 4841                        [아큐비즈 포켓 Acuviz Pocket 초음파]
# 4842                         [임상 한의사를 위한 기본 한약처방 강의 2판]
# 4843                                      [영어 진료 가이드북 ]
#
# [4844 rows x 2 columns]

# %%
from mlxtend.preprocessing import TransactionEncoder

# %%
pd.set_option('display.max_colwidth', -1)
transactions = [a[1]['name_x'].tolist() for a in list(train.groupby(['customer_id','date_paid']))]

# %%
te = TransactionEncoder()
te_ary = te.fit(transactions).transform(transactions)

# %% [markdown]
# # orders_1hot

# %%
orders_1hot = pd.DataFrame(te_ary, columns=te.columns_)
pf = orders_1hot.describe()

# %%
f = pf.iloc[0]-pf.iloc[3] # count - frequent
a = f.tolist()
b = list(f.index)
item = pd.DataFrame([[a[r],b[r]]for r in range(len(a))], columns=['Count','Item'])
item = item.sort_values(['Count'], ascending=False).head(10)
print("MOST POPULAR")
item
# Out:
# MOST POPULAR
#       Count                                     Item
# 1134  273    초음파 유도하 침 시술 가이드북
# 757   264    비만문답
# 1226  223    플로차트 정형외과 진단
# 730   223    방성혜 부인과 전문의서 처방 강의
# 749   205    부항컵 동방 일회용 1,000개
# 731   187    방성혜 피부과 전문의서 처방 강의
# 32    175    <도전! 베스트 강의> 올인원 패키지
# 996   152    윤상훈·권병조의 알짜 근육학
# 958   146    영어 진료 가이드북
# 722   110    미코 바이오메드 VERI-Q 코로나 신속항원진단키트 전문가용 (20T)

# %%
from mlxtend.frequent_patterns import apriori

# %%
is_ap = apriori(orders_1hot, min_support=0.01, max_len=3, use_colnames=True)
# Out:
# /home/user_4/anaconda3/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
is_ap.sort_values(by = ['support'], ascending = False).head(15)
# Out:
# /home/user_4/anaconda3/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#      support                                   itemsets
# 12  0.047561  (초음파 유도하 침 시술 가이드북)
# 7   0.045993  (비만문답)
# 13  0.038850  (플로차트 정형외과 진단)
# 4   0.038850  (방성혜 부인과 전문의서 처방 강의)
# 6   0.035714  (부항컵 동방 일회용 1,000개)
# 5   0.032578  (방성혜 피부과 전문의서 처방 강의)
# 1   0.030488  (<도전! 베스트 강의> 올인원 패키지)
# 11  0.026481  (윤상훈·권병조의 알짜 근육학)
# 9   0.025436  (영어 진료 가이드북 )
# 3   0.019164  (미코 바이오메드 VERI-Q 코로나 신속항원진단키트 전문가용 (20T))
# 0   0.018815  (2022 어르신 한의약 건강증진 사업 온라인 교육)
# 17  0.018467  (방성혜 부인과 전문의서 처방 강의, 방성혜 피부과 전문의서 처방 강의)
# 2   0.016899  (맘 편하게 한약 처방하기)
# 16  0.013415  (흔히보는 정형외과 외래진료 가이드북)
# 10  0.012195  (외래에서 꼭 알아야 할 통증증후군 137가지)

# %% [markdown]
# # Calculate Association Rules

# %%
from mlxtend.frequent_patterns import association_rules
# Out:
# /home/user_4/anaconda3/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
rules_confidence = association_rules(is_ap, min_threshold=0.01) # default가 confidence
rules_lift = association_rules(is_ap, metric= "lift", min_threshold=0.01)
display(rules_lift.tail())
# display(rules_confidence)
# Out:
# /home/user_4/anaconda3/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#             antecedents           consequents  antecedent support  \
# 0  (방성혜 부인과 전문의서 처방 강의)  (방성혜 피부과 전문의서 처방 강의)  0.038850
# 1  (방성혜 피부과 전문의서 처방 강의)  (방성혜 부인과 전문의서 처방 강의)  0.032578
#
#    consequent support   support  confidence       lift  leverage  conviction
# 0  0.032578            0.018467  0.475336    14.590537  0.017201  1.843889
# 1  0.038850            0.018467  0.566845    14.590537  0.017201  2.218951

# %%
rules_confidence_item = association_rules(is_ap, min) # default가 confidence
# rules_lift = association_rules(is_ap, metric= "lift", min_threshold=0.01)
# display(rules_lift)
display(rules_confidence_item)
# Out:
# /home/user_4/anaconda3/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-47-a0436a2d2fb4> in <module>
# ----> 1 rules_confidence_item = association_rules(is_ap, min) # default가 confidence
#       2 # rules_lift = association_rules(is_ap, metric= "lift", min_threshold=0.01)
#       3 # display(rules_lift)
#       4 display(rules_confidence_item)
#
# ~/anaconda3/lib/python3.8/site-packages/mlxtend/frequent_patterns/association_rules.py in association_rules(df, metric, min_threshold, support_only)
#     131     else:
#     132         if metric not in metric_dict.keys():
# --> 133             raise ValueError(
#     134                 "Metric must be 'confidence' or 'lift', got '{}'".format(metric)
#     135             )
#
# ValueError: Metric must be 'confidence' or 'lift', got '<built-in function min>'

# %%
display(rules_lift.sort_values(by=['support'], ascending = False).head(10))
display(rules_confidence.sort_values(by=['support'], ascending = False).head(10))
# Out:
# /home/user_4/anaconda3/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#             antecedents           consequents  antecedent support  \
# 0  (방성혜 부인과 전문의서 처방 강의)  (방성혜 피부과 전문의서 처방 강의)  0.038850
# 1  (방성혜 피부과 전문의서 처방 강의)  (방성혜 부인과 전문의서 처방 강의)  0.032578
#
#    consequent support   support  confidence       lift  leverage  conviction
# 0  0.032578            0.018467  0.475336    14.590537  0.017201  1.843889
# 1  0.038850            0.018467  0.566845    14.590537  0.017201  2.218951
#             antecedents           consequents  antecedent support  \
# 0  (방성혜 부인과 전문의서 처방 강의)  (방성혜 피부과 전문의서 처방 강의)  0.038850
# 1  (방성혜 피부과 전문의서 처방 강의)  (방성혜 부인과 전문의서 처방 강의)  0.032578
#
#    consequent support   support  confidence       lift  leverage  conviction
# 0  0.032578            0.018467  0.475336    14.590537  0.017201  1.843889
# 1  0.038850            0.018467  0.566845    14.590537  0.017201  2.218951

# %%
#  we can sort the association rules according to leverage value and find the most positively correlated item sets.
display(rules_lift.sort_values(by=['conviction'], ascending = False))
# Out:
# /home/user_4/anaconda3/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#             antecedents           consequents  antecedent support  \
# 1  (방성혜 피부과 전문의서 처방 강의)  (방성혜 부인과 전문의서 처방 강의)  0.032578
# 0  (방성혜 부인과 전문의서 처방 강의)  (방성혜 피부과 전문의서 처방 강의)  0.038850
#
#    consequent support   support  confidence       lift  leverage  conviction
# 1  0.038850            0.018467  0.566845    14.590537  0.017201  2.218951
# 0  0.032578            0.018467  0.475336    14.590537  0.017201  1.843889

# %% [markdown]
# # (1) Recommend Most Often Previously Purchased Items

# %%
tmp = train.groupby(['customer_id','name_x'])['date_paid'].agg('count').reset_index()
tmp.columns = ['customer_id','name_x','ct']
train = train.merge(tmp,on=['customer_id','name_x'],how='left')
train = train.sort_values(['ct','date_paid'],ascending=False)
train = train.drop_duplicates(['customer_id','name_x'])
train = train.sort_values(['ct', 'name_x'],ascending=False)
train
# Out:
# /home/user_4/anaconda3/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#        date_paid               customer_id                       name_x  \
# 375   2022-09-05  5e53b0f1bfe42609447827e4  흔히보는 정형외과 외래진료 가이드북
# 376   2022-08-30  5db15bc40dabe405b156f326  흔히보는 정형외과 외래진료 가이드북
# 377   2022-08-29  5e66dc73bfe42609447832fd  흔히보는 정형외과 외래진료 가이드북
# 378   2022-08-28  60a5abfdc1908b001a64756f  흔히보는 정형외과 외래진료 가이드북
# 379   2022-08-25  6079c3dfc1908b001a63e79f  흔히보는 정형외과 외래진료 가이드북
# ...          ...                       ...                  ...
# 7885  2022-08-05  61756b0c4cf9a5002288218a   동방 수침 10,000쌈 (100,000pcs)
# 374   2022-06-27  5ef6cc74334af8196b13c0bf   동방 수침 10,000쌈 (100,000pcs)
# 7886  2022-06-24  5dd6277c2bb59605ca3d055d   동방 수침 10,000쌈 (100,000pcs)
# 7887  2022-06-22  5d9a82d70dabe405b156de9b   동방 수침 10,000쌈 (100,000pcs)
# 7888  2022-06-22  62b2df1f08e04900234e132b   동방 수침 10,000쌈 (100,000pcs)
#
#                    product_ids     max_dat  diff_dat  ct_x  ct_y  ct
# 375   6182113bbc63410023473754  2022-09-05  0         1     1     1
# 376   6182113bbc63410023473754  2022-09-03  4         1     1     1
# 377   6182113bbc63410023473754  2022-08-29  0         1     1     1
# 378   6182113bbc63410023473754  2022-08-28  0         1     1     1
# 379   6182113bbc63410023473754  2022-08-25  0         1     1     1
# ...                        ...         ... ..        ..    ..    ..
# 7885  62b1318208e04900234e09ca  2022-08-05  0         1     1     1
# 374   62b1318208e04900234e09ca  2022-06-27  0         2     1     1
# 7886  62b1318208e04900234e09ca  2022-06-27  3         1     1     1
# 7887  62b1318208e04900234e09ca  2022-06-22  0         1     1     1
# 7888  62b1318208e04900234e09ca  2022-06-22  0         1     1     1
#
# [7889 rows x 9 columns]

# %% [markdown]
# # (2) Recommend Items Purchased Together

# %%
test[['customer_id','name_x','product_ids']]
# Out:
# /home/user_4/anaconda3/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#                     customer_id                                     name_x  \
# 56544  624e46e0d6b3320023ddcccc  메디TV Ep.39
# 56545  624e46e0d6b3320023ddcccc  메디TV Ep.39
# 56546  624e46e0d6b3320023ddcccc  메디TV Ep.39
# 56547  624e46e0d6b3320023ddcccc  메디TV Ep.39
# 56830  624e46e0d6b3320023ddcccc  메디TV Ep.39
# ...                         ...         ...
# 56820  5d66073d4e77525ec5ca171d  메디TV Ep.32
# 57329  5d66073d4e77525ec5ca171d  메디TV Ep.31
# 56937  5d96c1700dabe405b156db52  아크메시 사이드라인 스트레이트 엘라스틱 스크럽 남성 팬츠 DARK GRAY
# 56935  5d96c1700dabe405b156db52  다나침 두쌈용 1,000쌈 (10,000pcs)
# 56936  5d96c1700dabe405b156db52  아크메시 브이넥 프론트 3포켓 스크럽 남성 탑 DARK GRAY
#
#                     product_ids
# 56544  62d0ddac53948a002289824d
# 56545  62d0ddac53948a002289824d
# 56546  62d0ddac53948a002289824d
# 56547  62d0ddac53948a002289824d
# 56830  62d0ddac53948a002289824d
# ...                         ...
# 56820  62bbf28608e04900234e370c
# 57329  62c2924288c7dc00239bc031
# 56937  5ec680fae510ee503167b2ec
# 56935  5fe3ffec329d0c001aca7296
# 56936  5eb9112109982e0735b2d596
#
# [629 rows x 3 columns]

# %%
is_ap = apriori(orders_1hot, min_support=0.01, use_colnames=True)
rules_confidence_item = association_rules(is_ap, min_threshold=0.5) # default가 confidence
rules_confidence_item
# Out:
# /home/user_4/anaconda3/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#             antecedents           consequents  antecedent support  \
# 0  (방성혜 피부과 전문의서 처방 강의)  (방성혜 부인과 전문의서 처방 강의)  0.032578
#
#    consequent support   support  confidence       lift  leverage  conviction
# 0  0.03885             0.018467  0.566845    14.590537  0.017201  2.218951

# %%
apriori_items = rules_confidence_item[['antecedents','consequents']].iloc[:15]
# Out:
# /home/user_4/anaconda3/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
apriori_items['antecedents'] = apriori_items['antecedents'].apply(lambda x: list(map(str,x))[0])
apriori_items['consequents'] = apriori_items['consequents'].apply(lambda x: list(map(str,x))[0])
# Out:
# /home/user_4/anaconda3/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
apriori_items
# Out:
# /home/user_4/anaconda3/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#           antecedents         consequents
# 0  방성혜 피부과 전문의서 처방 강의  방성혜 부인과 전문의서 처방 강의

# %%
train_items = train[['date_paid','customer_id','name_x','product_ids']]

# apriori_items
# train_items[train_items['name_x']==]
train_items['apriori_pred'] = train_items['name_x'].apply(lambda x: apriori_items[apriori_items['antecedents']==x]['consequents'].values[0] if x in list(apriori_items['antecedents']) \
                            else None)
# for idx, row in train_items.iterrows():
# Out:
# /home/user_4/anaconda3/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
name_x_df = train_items.groupby('customer_id')['name_x'].unique().reset_index()
apriori_pred_df  = train_items.groupby('customer_id')['apriori_pred'].unique().reset_index()
real_pred = test.groupby('customer_id')['name_x'].unique().reset_index().rename(columns={'name_x':'real_product'})

train_pred = pd.merge(name_x_df,apriori_pred_df, on='customer_id', how='left')
train_real_pred = pd.merge(train_pred,real_pred, on='customer_id', how='right')
# Out:
# /home/user_4/anaconda3/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
train_real_pred
# Out:
# /home/user_4/anaconda3/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#                   customer_id  \
# 0    5d60cc294e77525ec5ca13e0
# 1    5d60cd634e77525ec5ca1402
# 2    5d60d0a94e77525ec5ca1446
# 3    5d60f53f4e77525ec5ca14e1
# 4    5d6293ad4e77525ec5ca15ba
# 5    5d64e80d4e77525ec5ca16e9
# 6    5d66073d4e77525ec5ca171d
# 7    5d6608b34e77525ec5ca171e
# 8    5d6644194e77525ec5ca1761
# 9    5d69cd4319efa30eb2913de3
# 10   5d6b822419efa30eb2913e13
# 11   5d6dc82019efa30eb2913ef2
# 12   5d6f2e4119efa30eb2913f88
# 13   5d6f724819efa30eb2914046
# 14   5d6f742019efa30eb29140ad
# 15   5d6f7cad19efa30eb291411e
# 16   5d6f870219efa30eb2914142
# 17   5d6f967319efa30eb291416e
# 18   5d6f9c0219efa30eb2914175
# 19   5d7059c019efa30eb29141dc
# 20   5d70ccd419efa30eb2914271
# 21   5d70de6819efa30eb29142c6
# 22   5d8342663f0e6805c4706714
# 23   5d843ef40dabe405b156d3cb
# 24   5d86d45a0dabe405b156d41d
# 25   5d886c5a0dabe405b156d48f
# 26   5d887cd30dabe405b156d491
# 27   5d8dfd2e0dabe405b156d58b
# 28   5d918f180dabe405b156d5e5
# 29   5d92f1180dabe405b156d606
# 30   5d968f550dabe405b156d85f
# 31   5d968f610dabe405b156d869
# 32   5d9693d40dabe405b156d9a1
# 33   5d96941c0dabe405b156d9ab
# 34   5d96995b0dabe405b156da56
# 35   5d96a6be0dabe405b156daf2
# 36   5d96ab5d0dabe405b156db10
# 37   5d96bec00dabe405b156db4e
# 38   5d96c1700dabe405b156db52
# 39   5d96fd5f0dabe405b156dbf0
# 40   5d9718280dabe405b156dd23
# 41   5d9722ef0dabe405b156dd42
# 42   5d9a87bc0dabe405b156df40
# 43   5d9a93100dabe405b156e07d
# 44   5d9f45500dabe405b156e400
# 45   5da03ede0dabe405b156e5d2
# 46   5da3bf350dabe405b156e866
# 47   5da43b0a0dabe405b156eaba
# 48   5db59b8b0dabe405b156f56b
# 49   5dc22ddf2bb59605ca3cf731
# 50   5dc3d5252bb59605ca3cf815
# 51   5dcb91872bb59605ca3cfcd3
# 52   5dce450a2bb59605ca3cffa2
# 53   5dd3af6f2bb59605ca3d0272
# 54   5dd6343d2bb59605ca3d059a
# 55   5dd914782bb59605ca3d06ea
# 33   [퍼슨 메딕코튼스왑 1kg (1팩), 통증치료를 위한 알기 쉬운 근골격계 이학적 검사법, 제일 갈근탕엑스과립, 온뜸 의료용 양면테이프, 부항컵 동방 일회용 100개, [멤버스] Medistream MEMBERS _구독가입형, [메디스트림 스탠다드] 육계 [거피] 500g, 베트남]
# 34   [성심 일회용 주사침 (기본사이즈) 100pcs, 초음파 유도하 침 시술 가이드북, 제일경옥고, 온뜸 의료용 양면테이프, 모나미 스킨라이너 Fine ]
# 35   [메디TV Ep.09 , 메디TV Ep.08 , 메디TV Ep.10 , 세이프란 전용 란셋 니들 26g (100pcs) 1box]
# 36   [인텍스 환자복, 아크메시 브이넥 싱글 포켓 스크럽 남성 탑 Navy, 아크메시 마레 사이드라인 스크럽 남성 팬츠 Navy]
# 37   [초음파 유도하 침 시술 가이드북, 부항컵 다나 일회용 1,000개, [메디스트림 스탠다드] 용안육(특특)(규) 600g, 태국 5묶음, [메디스트림 스탠다드] 시호[에이] 500g, 중국 5묶음, [메디스트림 스탠다드] 복령 500g, 중국 5묶음, [메디스트림 스탠다드] 백출[특] 500g, 중국 5묶음, [메디스트림 스탠다드] 맥문동 500g, 중국 5묶음, [메디스트림 스탠다드] 마황 500g, 중국 5묶음, [메디스트림 스탠다드] 당귀 500g, 한국 5묶음]
# 38   [아크메시 사이드라인 스트레이트 엘라스틱 스크럽 남성 팬츠 DARK GRAY, 아크메시 브이넥 프론트 3포켓 스크럽 남성 탑 DARK GRAY, 다나침 두쌈용 1,000쌈 (10,000pcs)]
# 39   [초음파 유도하 침 시술 가이드북]
# 40   [메디TV Ep.01 , 초음파 유도하 침 시술 가이드북]
# 41   [아큐비즈 포켓 Acuviz Pocket 초음파, 제주 옥돔, 갈치, 민어 情 5호 선물세트]
# 42   [수성 폴리글러브 M 200매, 수성 거즈 200매, [씨케이주식회사] 오미자(한국)(규) 600g, 한국, [대한한방] 녹원 대추(특,절편) (5묶음) 600g*5ea, 한국]
# 43   [아크메시 마레 오픈 넥 스크럽 남성 탑 Navy, Pointcare M4 혈액검사기 카트리지]
# 44   [의료용 냉각 스프레이 케미로사 100g]
# 45   [고빈도 한약재 8월 특가_[씨케이] 길경 (5묶음) 600g*5ea, 중국, 고빈도 한약재 8월 특가_[대연] 황기 (5묶음) 600g*5ea, 중국, 고빈도 한약재 8월 특가_[대연] 창출 (5묶음) 600g*5ea, 중국, 고빈도 한약재 8월 특가_[대연] 인삼 (5묶음) 600g*5ea, 한국, 고빈도 한약재 8월 특가_[대연] 대추 (5묶음) 600g*5ea, 한국, [씨케이주식회사] 황금 600g, 중국, [씨케이주식회사] 진피(陳皮) (5묶음) 600g*5ea, 중국, [씨케이주식회사] 죽여 600g, 중국, [씨케이주식회사] 육계[거피] (5묶음) 600g*5ea, 베트남, [씨케이주식회사] 복령 (5묶음) 600g*5ea, 중국, [씨케이주식회사] 강활[한국] 600g, 한국, [대연] 독활(한국) 600g, 한국]
# 46   [압구정 현대백화점 상주 곶감 너츠 혼합 세트, [한강주조] 나루생막걸리6도 3병 & 전용잔 2개]
# 47   [메디TV Ep.42, 메디TV Ep.41, 메디TV Ep.32 , 메디TV Ep.03 ]
# 64   [경혈학]
# 65   [배상면주가 오매락퍽 프리미엄 증류주, [씨케이주식회사] 방기 600g, 중국, [메디스트림 스탠다드] 시호[에이] 500g, 중국 5묶음]
# 66   [IR-VITA 적외선 ]
# 67   [안동농협 생강 500g, 부항컵 동방 일회용 1,000개, [씨케이주식회사] 제니 600g, 중국, [씨케이주식회사] 마황[중국] (5묶음) 600g*5ea, 중국]
# 68   [유니메드 유니쎈타주 (자하거 추출물) 2mL*20병]
# 69   [부항컵 동방 일회용 1,000개]
# ...
# 75   [수성 수술용 덴탈 마스크 50매, 동방 스프링침 한쌈용 1,000쌈 (10,000pcs)]
# 76   [SFT UltraGrip Latex PF glove 메디컴 울트라그립 라텍스 글러브, 3B 01. 인체 척추 모형 (모델명 : A58-3)_척추스탠드 A59-8 포함, 클린앤매직앤젤 혈흔제거제 150ml, 맘 편하게 한약 처방하기, [묶음 강의] 근골격계 약침의학 & 말초신경 약침의학, 조경하원장님의 최소자극도침 온라인 총론]
# 77   [성심 일회용 주사침 (기본사이즈) 100pcs, 동방 스프링침 두쌈용 1,000쌈 (10,000pcs), [멤버스] Medistream MEMBERS _구독가입형]
# 78   [아큐비즈 포켓 Acuviz Pocket 초음파, 맘 편하게 한약 처방하기, [멤버스] Medistream MEMBERS _구독가입형]
# 79   [메디TV Ep.02 , 메디TV Ep.06 , 메디TV Ep.34 , 맘 편하게 한약 처방하기, 메디TV Ep.38]
# 80   [메디TV Ep.32 , 메디TV Ep.07 , 메디TV Ep.39]
# 81   [메디TV Ep.41]
# 82   [[대연] 택사 600g, 한국, [대연] 향부자 600g, 한국, [대연] 산약 600g, 중국, [메디스트림 스탠다드] 용안육 (특특)(규) 600g, 태국, [대연] 마황 600g, 중국, [대연] 복령 600g, 중국]
# 83   [메디TV Ep.01 , SMC침 한쌈용 1,000쌈 (10,000pcs)]
# 84   [한의 피부진료 첫 걸음, HAPPY 소아청소년 진료, 한방피부진료레슨, 영어 진료 가이드북 , 아큐비즈 포켓 Acuviz Pocket 초음파]
# 85   [아큐비즈 포켓 Acuviz Pocket 초음파, [온누리] 녹용 분골(특) 600g,뉴질랜드]
# 86   [아큐비즈 포켓 Acuviz Pocket 초음파]
# 87   [정우 오적산산제 150포 (50일분/1회 용량 4.35g), 부항컵 동방 일회용 1,000개, 우전 E-밴드 15mm (2,000pcs x 1박스), 정우 연교패독산산제 150포 (50일분/1회 용량 2.91g), 포장기 스텐 거름망 A형, 세이프란 전용 란셋 니들 26g (100pcs) 1box, 정우 불환금정기산산제 150포 (50일분/1회 용량 2.66g), 포장기 스텐 거름망 B형, 다나침 한쌈용 1,000쌈 (10,000pcs)]
# 88   [아스토니쉬 스테인리스 광택 클리너 750ml, 아스토니쉬 패브릭 리프레셔 750ml, 아스토니쉬 윈도우 클리너 750ml, 아스토니쉬 배스룸 클리너 750ml, [씨케이주식회사] 창이자 600g, 중국, [씨케이주식회사] 오가피 600g, 중국, [씨케이주식회사] 용안육(특특)(규) (5묶음) 600g*5ea, 태국, [씨케이주식회사] 사인[추말 타원형] 600g, 미얀마, [씨케이주식회사] 백편두 600g, 미얀마, [씨케이주식회사] 복령 (5묶음) 600g*5ea, 중국, 고빈도 한약재 특가_[씨케이] 석고 (5묶음) 600g*5ea, 중국, [씨케이주식회사] 내복자[추말] 600g, 인도, [씨케이주식회사] 황기(편) (5묶음) 600g*5ea, 중국, 고빈도 한약재 특가_[씨케이] 천궁 (5묶음) 600g*5ea, 중국, [신흥제약] 숙지황(원형) 1kg, 중국, [씨케이주식회사] 마인[추말] 600g, 중국, 고빈도 한약재 특가_[씨케이] 숙지황[대통 500g] (5묶음) 500g*5ea, 중국, [씨케이주식회사] 모과 600g, 중국, [씨케이주식회사] 감초[키르키] (5묶음) 600g*5ea, 키르키즈스탄]
# 89   [메디TV Ep.03 ]
# 90   [Kendall 자세와 통증치료에 있어서 근육의 기능과 검사 5판, 맥학심오 강의, 의학입문 맥학강의, 개원의를 위한 통증사냥법]
# 91   [메디TV Ep.44, 메디TV Ep.43, 메디TV Ep.21 , 메디TV Ep.06 , 메디TV Ep.10 , 안동농협 생강 500g]
# 92   [실전, 임상한의학 내과질환을 중심으로, 일차진료 한의사를 위한 보험한약입문 - 둘째 판, 플로차트 정형외과 진단, 음양승강으로 해석하는 사상의학: 생리병리, 증례와 함께 하는 한약처방]
# 93   [초음파젤 청색 바디용 250ml (BETASONIC), 온뜸 의료용 양면테이프, 세이프란 전용 란셋 니들 26g (100pcs) 1box, 동방 티이침 (1,000pcs)]
# 94   [정결안 마치현 토닉 100ml, 정결안 설파 클레이 크림 마스크 300g, 정결안 알로에베라젤 500ml, 정결안 수윤 크림 200g, 정결안 설파젤 60ml]
# 95   [메디TV Ep.06 , 메디TV Ep.02 , 메디TV Ep.34 ]
# 96   [[씨케이주식회사] 황기(편) 600g, 중국, [씨케이주식회사] 마황[중국] (5묶음) 600g*5ea, 중국, [씨케이주식회사] 후박[거피] 600g, 중국, 고빈도 한약재 특가_[씨케이] 석고 (5묶음) 600g*5ea, 중국, [대연] 작약 600g, 중국, [대연] 인삼 600g, 한국, 맘 편하게 한약 처방하기]
# 97   [아큐비즈 포켓 Acuviz Pocket 초음파, [세트] 말초신경 약침의학, 근골격계 약침의학, 스파이랄 및 키네지오 테이핑]
# 98   [동방 아큐프로 needle 카트리지 (15개) 6박스, 살색 MOALAB BAND 100매 20케이스, 크라시에 방풍통성산 엑스세립]
# 99   [퍼슨 성광 알파 헥시딘 500ml 1개, 수성 탈지면-엔 4x4cm (450g) 10개 (커트솜)(1박스), OK메디칼 두타베드]
# 100  [메디TV Ep.02 , 메디TV Ep.04 , 개원의를 위한 통증사냥법]
# 101  [메디TV Ep.39, 메디TV Ep.38, 메디TV Ep.37, 메디TV Ep.36, 맘 편하게 한약 처방하기]
# 102  [메디TV Ep.09 , 메디TV Ep.35, 메디TV Ep.37, 메디TV Ep.38, 메디TV Ep.36, 메디TV Ep.27 , 메디TV Ep.05, 메디TV Ep.41, 메디TV Ep.39]

# %%
# 아이템 맞춘 개수
cnt = 0
for preds, reals in zip(train_real_pred['apriori_pred'], train_real_pred['real_product']):
    for pred in preds:
        if pred in reals:
            cnt += 1
cnt
# Out:
# /home/user_4/anaconda3/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# 0
